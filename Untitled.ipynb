# %%
import requests
import json
import pandas as pd
api_request = requests.get('https://sandbox.iexapis.com/stable/stock/market/batch?symbols=aapl,fb,tsla,jblu,amzn,peix,mrna,msft,csco,intc&types=chart&range=1m&last=5&token=Tsk_6528e864eb8d4f008715b7d64fbec8da')

# %%
api = json.loads(api_request.content)

# %%
api
# Out:
# {'AAPL': {'chart': [{'date': '2020-10-21',
#     'open': 119.05,
#     'close': 122.52,
#     'high': 123.03,
#     'low': 119.87,
#     'volume': 91114333,
#     'uOpen': 117.73,
#     'uClose': 120.04,
#     'uHigh': 122.44,
#     'uLow': 118.38,
#     'uVolume': 90270620,
#     'change': 0,
#     'changePercent': 0,
#     'label': 'Oct 21',
#     'changeOverTime': 0},
#    {'date': '2020-10-22',
#     'open': 122.12,
#     'close': 119.65,
#     'high': 119.74,
#     'low': 118.2,
#     'volume': 106307892,
#     'uOpen': 117.5,
#     'uClose': 116.71,
#     'uHigh': 119.69,
#     'uLow': 116.49,
#     'uVolume': 102141832,
#     'change': -1.14,
#     'changePercent': -0.9684,
#     'label': 'Oct 22',
#     'changeOverTime': -0.009866},
#    {'date': '2020-10-23',
#     'open': 119.92,
#     'close': 117.56,
#     'high': 118.55,
#     'low': 115.75,
#     'volume': 83876830,
#     'uOpen': 122.13,
#     'uClose': 116.41,
#     'uHigh': 120.66,
#     'uLow': 119.18,
# ...
